# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelaEm/skolprojekt/blob/main/grunder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Py och Kode går på Randbergaskolan och tillsammans med sin klass samlar de pengar till en klassresa. Första uppgiften blir att planera ett disco för de yngre barnen på skolan. De har en väldigt jobbig lärare som säger att hen gärna hjälper till, men att de i så fall behöver lära sig Python och använda det i sin planering. SUCK! Men bara att börja jobba...

# %%
#Detta är en kommentar.
#Vad tror du kommer visas när du trycker på play?
#Testa!

print("Hej!")
print("Jag heter Py.")
print("Detta är en string!")
print('Välkommen på disco!')

# %%
#Skriv ett eget meddelande och skicka till din lärare

# %%
#Detta ser ju lite konstigt ut... \n, vad kan det betyda egentligen?
print("Hej!\nJag heter Kode.\nVälkommen på disco.")

# %%
#Skriv ut tre olika meningar på tre olika rader men använd bara print() en gång. Får du till det?

# %%
#Vad är det som är fel här? Kan du rätta felet?
print(Hej på dig!)

# %%
#Varför är inte detta fel?
print(7)

# %% [markdown]
# Svar:

# %%
#Varför är inte detta fel?
print(True)

# %% [markdown]
# Svar:

# %%
#Skriv ut en textsträng, en siffra och en boolean. Kan du lösa det med en print()? (Ledtråd; ,)
print("Hej", 7, False)

# %% [markdown]
# Man vill ofta spara värden när man programmerar. För att spara ett värde använder man en variabel. Man bestämmer värdet av variabeln genom att skriva ett namn på den. (OBS, inga stora bokstäver eller siffror i början!) och sedan = och till sist ett värde.

# %%
#Ändra till vilka värden du vill och skriv ut
name = "Py"
age = 14
favorite_food = ["Pizza", "Hamburgare"]
likes_math = True

print(name)
print(age)
print(favorite_food)
print(likes_math)

#UTMANING: Kan du skriva ut alla variabler med en enda print()? (Ledtråd: ,)

# %%
name = "Kode"
age = 15

#Om jag vill sätta in mina variabler i en mening kan jag skriva ett f framför min mening och sätta in mina variabler i {}. Testa att köra koden.

print(f"Hej! Jag heter {name} och jag är {age} år gammal.")
# Out:
# Hej! Jag heter Kode och jag är 15 år gammal.

# %%
#Gör en variabel first_name, en variabel last_name och en variabel school. Skriv sedan ut en mening där du sätter in variablerna.

# %%
#Ibland kanske man vill få in ett värde från användaren. Då använder man funktionen input().

name = input("Vad heter du?")
print(f"Hej {name}!")

#Utmaning: Kan du få svarsrutan att stå under frågan? Kan du skapa lite mer mellanrum till svaret? Fråga också efter ålder och spara i en variabel och skriv ut en mening med både namn och ålder.

# %%
#Vad tror du kommer skrivas ut här?
tal1 = 5
tal2 = 7
print(tal1 + tal2)

#Testa med olika tal och olika räknesätt!

# %%
#Tänk på prioriteringsreglerna. Vad borde svaret bli? Klarar programmet prioriteringsreglerna?

x = 2
y = 5
z = 7

print(x + y * z)
