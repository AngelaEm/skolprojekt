# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelaEm/skolprojekt/blob/main/grunder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Detta är en kommentar.

print("Hej!")
print("Jag heter Anna.")
print("Detta är en string!")
print('Detta är också en string.')
# Out:
# Hej!
# Jag heter Anna.
# Detta är en string!
# Detta är också en string.

# %%
print("Hej!" + "Jag heter Anna." + "Detta är en string.")
print("Hej!" + " Jag heter Anna. " + "Detta är en string.")
print("Hej!\nJag heter Anna.\nDetta är en string.")
print("1.\tHej!\n2.\tJag heter Anna.\n3.\tDetta är en string.")
# Out:
# Hej!Jag heter Anna.Detta är en string.
# Hej! Jag heter Anna. Detta är en string.
# Hej!
# Jag heter Anna.
# Detta är en string.
# 1.	Hej!
# 2.	Jag heter Anna.
# 3.	Detta är en string.

# %%
print("""Så här kan man
skriva en jättelång string

på flera olika rader.""")
# Out:
# Så här kan man
# skriva en jättelång string
#
# på flera olika rader.

# %% [markdown]
# #Rubrik
# ##Här kan man skriva...
# ###Kommentarer i .md
# Man kan bara skriva vanlig text också.
#
#
# ```
# print("Exempel")
# ```
#
#
# *   **Fet stil**
# *   *Kursiv stil*
#
#
# 1.   Post i listan
# 2.   Post i listan

# %%
print("Hej!\n" * 5)
# Out:
# Hej!
# Hej!
# Hej!
# Hej!
# Hej!

# %%
print("Hej!")
name = input("Vad heter du?\n")
print("Hej " + name + "!")
menu = "Hamburgare 100SEK, Pizza 100SEK, Pasta 100SEK, Sallad 100SEK"
print(f"{name}, vad vill du äta idag? Detta är vår meny:\n{menu}\n")
order = input("Vad vill du äta?\n")
print(f"Då kommer din {order} snart.")
# Out:
# Hej!
# Vad heter du?
# anna
# Hej anna!
# anna, vad vill du äta idag? Detta är vår meny:
# Hamburgare 100SEK, Pizza 100SEK, Pasta 100SEK, Sallad 100SEK
#
# Vad vill du äta?
# pizza
# Då kommer din pizza snart.

# %%
name = "Angela"
age = 48
actual_age = 48.5

print(f"Jag heter {name} och jag är {age} eller egentligen {actual_age} år gammal.")

print(type(name))
print(type(age))
print(type(actual_age))
print(age + 4)
print(age + 2 * 10)
upphojt = 4 ** 2
print("4*4 = " + str(upphojt))
# Out:
# Jag heter Angela och jag är 48 eller egentligen 48.5 år gammal.
# <class 'str'>
# <class 'int'>
# <class 'float'>
# 52
# 68
# 4*4 = 16

# %%
choice = input("Vad vill du äta idag? " + menu + "\n")
antal = input("Hur många " + choice + " vill du ha?\n")
price = 100
print("Då betalar du: " + str(int(antal) * price) + "kr")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3850973037.py in <cell line: 0>()
# ----> 1 choice = input("Vad vill du äta idag? " + menu + "\n")
#       2 antal = input("Hur många " + choice + " vill du ha?\n")
#       3 price = 100
#       4 print("Då betalar du: " + str(int(antal) * price) + "kr")
#
# NameError: name 'menu' is not defined

# %%
name = input("Vad heter du?\n")
if name == "Ben":
  control_question = input("Är du elak?")
  if control_question.lower() == "ja":
    print("Get out " + name + "!!!!")
    exit()
  else:
    print("Välkommen " + name + "!!!!")
else:
  print("Välkommen " + name + "!!!!")
# Out:
# Vad heter du?
# Ben
# Är du elak?nej
# Välkommen Ben!!!!

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1692789099.py in <cell line: 0>()
# ----> 1 print(choice)
#
# NameError: name 'choice' is not defined
